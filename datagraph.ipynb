# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dataset = pd.read_csv('datasetcor.csv')

# %%
dataset.columns
# Out:
# Index(['Temperature', 'Flow velocity', 'CO2 pressure', 'Internal pressure',
#        'Corrosion Inhibitor efficiency', 'Shear stress', 'pH',
#        'Corrosion rate'],
#       dtype='object')

# %%
len(dataset.Temperature)
# Out:
# 243

# %%
dataset.describe(include="all")
# Out:
#        Temperature  Flow velocity  CO2 pressure  Internal pressure  \
# count   243.000000     243.000000    243.000000         243.000000
# mean     40.000000       1.500000      1.500000          65.000000
# std       8.181818       0.245455      0.409091           4.090909
# min      30.000000       1.200000      1.000000          60.000000
# 25%      30.000000       1.200000      1.000000          60.000000
# 50%      40.000000       1.500000      1.500000          65.000000
# 75%      50.000000       1.800000      2.000000          70.000000
# max      50.000000       1.800000      2.000000          70.000000
#
#        Corrosion Inhibitor efficiency  Shear stress          pH  \
# count                      243.000000    243.000000  243.000000
# mean                        50.000000      4.000000    3.918519
# std                          8.181818      0.818182    0.067010
# min                         40.000000      3.000000    3.800000
# ...

# %%
sns.boxplot(x="CO2 pressure", y="Corrosion rate", data=dataset)
# Out:
# <AxesSubplot: xlabel='CO2 pressure', ylabel='Corrosion rate'>

# %%
sns.countplot(x=)

# %%
sns.pairplot(dataset).fig.suptitle("CO2 Corrosion", y=1.01)
#sns.pairplot(dataset,hue='Variant_Suspect').fig.suptitle("Pair Plot Covid Jakarta", y=1.01)
# Out:
# Text(0.5, 1.01, 'CO2 Corrosion')
